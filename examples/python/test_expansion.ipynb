# %%
from mpart import *
import numpy as np
import matplotlib.pyplot as plt

n = 100
x = np.linspace(-2,2,n)
x = x.reshape(1,n)

opts = MapOptions()
map_order = 2
map_1d = CreateTriangular(1,1,map_order,opts)


coeffs = np.random.randn(map_1d.numCoeffs)
map_1d.SetCoeffs(coeffs) 
f1 = map_1d.GetComponent(0).GetBaseFunction()
#f1.SetCoeffs(coeffs)
f1 = map_1d.GetComponent(0).GetBaseFunction()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/paul-baptiste/Documents/code/MParT/examples/python/test_expansion.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/paul-baptiste/Documents/code/MParT/examples/python/test_expansion.ipynb#ch0000000?line=0'>1</a> from mpart import *
#       <a href='vscode-notebook-cell:/Users/paul-baptiste/Documents/code/MParT/examples/python/test_expansion.ipynb#ch0000000?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/paul-baptiste/Documents/code/MParT/examples/python/test_expansion.ipynb#ch0000000?line=2'>3</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'mpart'
